# %%
import argparse
import json
import os
import time
import numpy as np
from tqdm import tqdm

#Add openai key here
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# completion = client.chat.completions.create(
#   model="gpt-3.5-turbo",
#   messages=[
#     {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
#     {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
#   ]
# )

# print(completion.choices[0].message)

# %%
questions = []
questions_path = '/root/LLaVA-Recipe/llava/eval/table/question_recipe_1k_3q.jsonl'
with open(questions_path, 'r') as file:
    for lines in file:
        data = json.loads(lines)
        questions.append(data)
print(questions)
print(len(questions))
# Out:
# [{'image': '7a4833e18e.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '7a4833e18e.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '7a4833e18e.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '59434caadc.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '59434caadc.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '59434caadc.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': 'a75a21cb56.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': 'a75a21cb56.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': 'a75a21cb56.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '8c91371c2d.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '8c91371c2d.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '8c91371c2d.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '3e6ad4ce76.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '3e6ad4ce76.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '3e6ad4ce76.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '89c9892c1b.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '89c9892c1b.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '89c9892c1b.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '2633cc5fd0.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '2633cc5fd0.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '2633cc5fd0.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '7dac8bc1fc.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '7dac8bc1fc.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '7dac8bc1fc.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '905dcd688e.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '905dcd688e.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '905dcd688e.jpg', 'question_id': 3, 'text': 'What cooking method is used for the food shown in this image?', 'category': 'generic'}, {'image': '2ee3497caf.jpg', 'question_id': 1, 'text': 'What recipe can be made with the items in this image?', 'category': 'generic'}, {'image': '2ee3497caf.jpg', 'question_id': 2, 'text': 'How should the food in this picture be prepared?', 'category': 'generic'}, {'image': '2ee3497caf.jpg', 'question_id': 3, 'text': 'What co ...
# 900

# %%
answer1 = []
answer1_path = '/root/LLaVA-Recipe/llava/eval/table/answer/answer-7b-IIM-e1.jsonl'
with open(answer1_path, 'r') as file:
    for lines in file:
        data = json.loads(lines)
        answer1.append(data)
print(answer1)
print(len(answer1))
# Out:
# [{'image': '7a4833e18e.jpg', 'question_id': 1, 'prompt': 'What recipe can be made with the items in this image?', 'text': 'The image shows a combination of ingredients that can be used to create a delightful treat. You can use these ingredients to make a delicious cupcake with a unique twist.', 'answer_id': 'QrtY4HUY7yBXsqq64ENrnp', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': '7a4833e18e.jpg', 'question_id': 2, 'prompt': 'How should the food in this picture be prepared?', 'text': 'In the image, the food is prepared by combining the sugar, flour, baking powder, salt, and cinnamon in a bowl. Then, butter and egg are added to the mixture and mixed until smooth. The batter is then divided into 12 muffin cups and baked in the oven until golden brown.', 'answer_id': 'H2tAhuvKZmJtfr5kLJwiGb', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': '7a4833e18e.jpg', 'question_id': 3, 'prompt': 'What cooking method is used for the food shown in this image?', 'text': 'The food in the image is prepared using a microwave cooking method. It involves heating a mixture of sugar, butter, and milk in the microwave until the sugar dissolves and the butter melts. This method is convenient and quick, allowing the mixture to be heated to the desired temperature without the need for a stove or oven.', 'answer_id': '9FH2STK2iusZ7HDaN9YtTa', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_id': 1, 'prompt': 'What recipe can be made with the items in this image?', 'text': 'The image showcases a delightful dish that involves a combination of ingredients. It includes shrimp, potatoes, onions, garlic, lemon, and a flavorful seasoning mix. When prepared together, these ingredients create a delicious and satisfying meal that is perfect for any occasion.', 'answer_id': '3ppV8SYweTEm8VuVpep8bB', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_id': 2, 'prompt': 'How should the food in this picture be prepared?', 'text': 'The dish in the image features a flavorful combination of ingredients. It includes a delicious mix of butter, lemon juice, garlic, and a variety of seasonings like salt, pepper, and paprika. The key to preparing this dish is to first cook the shrimp until they are pink and then mix them with the butter mixture. Finally, the dish is topped with a generous amount of shredded cheese before being baked to perfection.', 'answer_id': 'dGe9RTGTD7XrEwMWTFMm3A', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_id': 3, 'prompt': 'What cooking method is used for the food shown in this image?', 'text': 'The dish in the image is prepared using a broiler method. The fish is placed on a broiler pan and baked in the oven until it reaches the desired level of doneness. This cooking method helps to achieve a crispy exterior while keeping the fish moist and tender inside.', 'answer_id': '3AnXgfxd9XZHhJvhje8VaV', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': 'a75a21cb56.jpg', 'question_id': 1, 'prompt': 'What recipe can be made with the items in this image?', 'text': 'The image shows a combination of ingredients that can be used to create a flavorful dish. You can use these ingredients to make a delicious roasted chicken with aromatic herbs and spices. The roasted chicken is seasoned with a blend of spices like paprika, garlic powder, and onion powder, giving it a rich and savory taste.', 'answer_id': 'VeEq7KMAbhWu34qX3V3UPE', 'model_id': 'llava-lora-7b-10K-IIM-e1', 'metadata': {}}, {'image': 'a75a21cb56.jpg', 'question_id': 2, 'prompt': 'How should the food in this picture be prepared?', 'text': 'The food in the picture is a delightful combination of almonds, garlic, rosemary, and sea salt. To prepare it, you would need to toast the almonds in a skillet until they are lightly browned and fragrant. Then, you would add garlic, rosemary, and sea salt to the skillet and stir ...
# 300

# %%
answer2 = []
answer2_path = '/root/LLaVA-Recipe/llava/eval/table/answer/answer_llava-7b.jsonl'
with open(answer2_path, 'r') as file:
    for lines in file:
        data = json.loads(lines)
        answer2.append(data)
print(answer2)
print(len(answer2))
# Out:
# [{'image': '7a4833e18e.jpg', 'question_id': 1, 'prompt': 'What recipe can be made with the items in this image?', 'text': 'The image features a cupcake with a blackberry on top, sitting on a blue table. To make a cupcake with a blackberry on top, you would need the following ingredients: cupcake batter, blackberries, powdered sugar, and a cupcake liner. You can either bake the cupcake batter in a cupcake pan or use a muffin tin to create the cupcake. Once the cupcake is baked, you can remove it from the pan and let it cool. Then, you can top the cupcake with a blackberry, and sprinkle powdered sugar on top. Finally, you can place the cupcake in a cupcake liner and serve it. This recipe is a simple and delicious way to enjoy a cupcake with a touch of fruit flavor.', 'answer_id': 'VuikWmHYQo7kZBDoqVRhbL', 'model_id': 'llava-v1.5-7b', 'metadata': {}}, {'image': '7a4833e18e.jpg', 'question_id': 2, 'prompt': 'How should the food in this picture be prepared?', 'text': 'In the image, there is a cupcake with a blackberry on top, sitting on a blue table. To prepare the cupcake, you should start by following the recipe for the cupcake batter, which typically includes ingredients such as flour, sugar, butter, eggs, and a leavening agent like baking powder or baking soda. Once the batter is prepared, you can use a cupcake pan to evenly distribute the batter and bake the cupcakes according to the recipe instructions. After baking, you can remove the cupcakes from the pan and let them cool on a wire rack.\n\nTo add the blackberry on top, you can gently press the blackberry onto the cupcake while it is still warm. This will help the blackberry adhere to the cupcake and maintain its shape. Finally, you can serve the cupcake and enjoy it as a delicious treat.', 'answer_id': 'fwLSoQBuRhJg4zEqGjYddk', 'model_id': 'llava-v1.5-7b', 'metadata': {}}, {'image': '7a4833e18e.jpg', 'question_id': 3, 'prompt': 'What cooking method is used for the food shown in this image?', 'text': 'The food shown in the image, which is a cupcake, is baked.', 'answer_id': 'Vd3capde6vaqV4deECdnWk', 'model_id': 'llava-v1.5-7b', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_id': 1, 'prompt': 'What recipe can be made with the items in this image?', 'text': 'The image features a piece of fish, possibly a fish cake, with a slice of lemon on top. This suggests that a recipe for fish cake with lemon can be made using the items in the image. To make this dish, one would need to prepare the fish cake by combining fish, breadcrumbs, and other ingredients, such as onions, herbs, and spices. Once the fish cake is formed, it can be baked or fried until cooked through. Afterward, the slice of lemon can be placed on top of the fish cake to add a burst of fresh flavor and a touch of color to the dish. This simple yet delicious recipe can be enjoyed as a main course or appetizer, and the lemon slice can be easily removed before serving.', 'answer_id': 'PhMr9gxGQXfpp7DTFXk2ry', 'model_id': 'llava-v1.5-7b', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_id': 2, 'prompt': 'How should the food in this picture be prepared?', 'text': 'The food in the image is a stuffed fish, which is covered with breadcrumbs and topped with lemon wedges. To prepare this dish, you should first clean and fillet the fish, removing any bones and fins. Then, stuff the fish with your desired filling, such as breadcrumbs, herbs, or other ingredients. Once the fish is stuffed, coat it with breadcrumbs to create a crispy exterior. Finally, place the lemon wedges on top of the breaded fish, ensuring that they are evenly distributed. This will add a burst of citrus flavor to the dish when the fish is cooked. You can cook the fish in a pan or oven, using a little oil to ensure even cooking. Once cooked, the fish should be served with the lemon wedges on the side for guests to enjoy.', 'answer_id': 'LY8NP7yQNADixawn8GJjRZ', 'model_id': 'llava-v1.5-7b', 'metadata': {}}, {'image': '59434caadc.jpg', 'question_ ...
# 300

# %%
role = 'Assistant'
prompt = "We would like to request your feedback on the performance of two AI assistants in response to the user question displayed later.\nPlease rate the helpfulness, relevance, accuracy, level of details of their responses. Each assistant receives an overall score on a scale of 1 to 10, where a higher score indicates better overall performance.\nPlease first output a single line containing only two values indicating the scores for Assistant 1 and 2, respectively. The two scores are separated by a space.\nIn the subsequent line, please provide a comprehensive explanation of your evaluation, avoiding any potential bias and ensuring that the order in which the responses were presented does not affect your judgment."

# %%
contexts = []
contexts_path = '/root/LLaVA-Recipe/dataset/recipe1m/test_label/test1K.json'
with open(contexts_path, 'r') as file:
    all_data = json.load(file)
    for data in all_data:
        context = 'dish name: ' + data['title'] + '.\n' + 'Ingredients: ' + data['ingredients'] + '.\n' + 'Instructions: ' + data['instructions'] + '.'
        contexts.append(context)
print(contexts)
print(len(contexts))
print(contexts[0])
# Out:
# ['dish name: Wild Blackberry Vanilla Cupcakes.\nIngredients: 1 cup Unsalted Butter, Room Temperature,1-23 cup Granulated Sugar,4 whole Eggs,1 Tablespoon Vanilla Extract,3 cups All-purpose Flour,1 Tablespoon Baking Powder,1/2 teaspoons Baking Soda,1- 1/4 cup Buttermilk,2 cups Blackberries,2 cups (or As Needed) Buttercream Icing, Your Preference,Sanding Sugar, As Needed.\nInstructions: Preheat oven to 350 degrees F (180 degrees C). In a mixer bowl fitted with a paddle attachment, beat butter with sugar until light and fluffy (a few minutes). Beat in eggs, one at a time, beating well after each addition. Beat in vanilla. Whisk together flour, baking powder, baking soda and salt. Stir dry mixture into wet (butter) mixture alternately with buttermilk, making 3 additions of dry ingredients and 3 of buttermilk. Fold in blackberries. Using an ice cream scoop or 1/4-cup measurer, scoop batter into a muffin tin lined with cupcake liners. Bake for approximately 15-20 minutes, until cake tester (toothpicks or skewers work well too) inserted in centre comes out clean. Let cool in muffin tins for about 5 minutes, then remove and let cool completely before adding icing. Pipe a swirl of icing on top of cupcake, and roll the iced cupcakes in a bowl of sanding sugar. Top with a blackberry or decoration of choice and enjoy! Note: You can find a vanilla buttercream icing recipe in my recipe box..', 'dish name: Stuffed Flounder La Fourche.\nIngredients: 4 flounder (1 1/2 lbs each),12 lb lump crabmeat,12 lb shrimp,1 egg (beaten),1 lemon, juice of,1 cup breadcrumbs,1 12 cups dry white wine,2 garlic cloves, minced,12 cup celery, finely diced,3 tablespoons chopped parsley,12 cup green onion, sliced,salt, Black pepper and cayenne, to taste,1 lb butter, unsalted,12 teaspoon paprika.\nInstructions: In a heavy pan, saute onions, celery and garlic in the butter over medium heat. When vegetables are soft, add shrimp, crab, egg and remaining ingredients except wine and paprika. Slice each flounder on the dark side down the middle. Slice toward the sides making a pocket under the meat large enough to place the seafood stuffing. Season the stuffing to taste. Fill the pocket, leaving a mound on top. Place in a pan with 1 1/2 cups of dry white wine. This will keep the flounder moist and keep it from sticking. NOTE: it helps to rub butter on the pan. Sprinkle paprika on the top and bake for 25 minutes in a 3750 F oven..', 'dish name: Rosemary Roasted Almonds.\nIngredients: 1 tablespoon finely chopped fresh rosemary,1 tablespoon extra-virgin olive oil,1 teaspoon chile powder,3/4 teaspoon kosher salt,Dash of ground red pepper,1 (10-ounce) bag whole almonds (about 2 cups).\nInstructions: 1. Preheat oven to 325.2. Combine all ingredients in a medium bowl; toss to coat. Arrange nut mixture in a single layer on a baking sheet lined with foil. Bake at 325 for 20 minutes or until lightly toasted. Cool to room temperature..', 'dish name: Meatless Mincemeat.\nIngredients: 1 large orange,1 small lemon,1 (15 ounce) box seedless raisins,3 lbs tart apples, cored (9 medium),1 12 cups apple cider,3 cups firmly packed brown sugar,1 12 teaspoons salt,1 12 teaspoons ground cinnamon,1 12 teaspoons nutmeg,1 12 teaspoons cloves.\nInstructions: Remove seeds from orange and lemon. Using coarse blade, force fruit through food chopper with raisins and unpeeled apples. Add cider. Put in kettle and bring to boil. Simmer, uncovered, for 15 minutes. Add remaining ingredients, and simmer for 20 minutes longer, or until thick. Makes enough filling for three 9-inch pies..', 'dish name: Taralli Italian Style Breadsticks.\nIngredients: 160 grams Bread (strong) flour,40 grams Cake flour,1 grams Dry yeast,10 grams Sugar,4 grams Salt,1 grams Basil (dried),1/2 grams Rosemary (dried),115 grams Water,6 grams Olive oil,1 Olive oil,1 Salt.\nInstructions: Combine the ingredients for the dough and knead until smooth. Let rise for 40 minutes at a temperature of 30C for the first proving. Since there is only  ...
# 1000
# dish name: Wild Blackberry Vanilla Cupcakes.
# Ingredients: 1 cup Unsalted Butter, Room Temperature,1-23 cup Granulated Sugar,4 whole Eggs,1 Tablespoon Vanilla Extract,3 cups All-purpose Flour,1 Tablespoon Baking Powder,1/2 teaspoons Baking Soda,1- 1/4 cup Buttermilk,2 cups Blackberries,2 cups (or As Needed) Buttercream Icing, Your Preference,Sanding Sugar, As Needed.
# Instructions: Preheat oven to 350 degrees F (180 degrees C). In a mixer bowl fitted with a paddle attachment, beat butter with sugar until light and fluffy (a few minutes). Beat in eggs, one at a time, beating well after each addition. Beat in vanilla. Whisk together flour, baking powder, baking soda and salt. Stir dry mixture into wet (butter) mixture alternately with buttermilk, making 3 additions of dry ingredients and 3 of buttermilk. Fold in blackberries. Using an ice cream scoop or 1/4-cup measurer, scoop batter into a muffin tin lined with cupcake liners. Bake for approximately 15-20 minutes, until cake tester (toothpicks or skewers work well too) inserted in centre comes out clean. Let cool in muffin tins for about 5 minutes, then remove and let cool completely before adding icing. Pipe a swirl of icing on top of cupcake, and roll the iced cupcakes in a bowl of sanding sugar. Top with a blackberry or decoration of choice and enjoy! Note: You can find a vanilla buttercream icing recipe in my recipe box..

# %%
NUM_SECONDS_TO_SLEEP = 0.5

def get_eval(content: str, max_tokens: int):
    while True:
        try:
            response = client.chat.completions.create(
                model='gpt-3.5-turbo',
                messages=[{
                    'role': 'system',
                    'content': 'You are a helpful and precise assistant for checking the quality of the answer.'
                }, {
                    'role': 'user',
                    'content': content,
                }],
                temperature=0.2,  # TODO: figure out which temperature is best for evaluation
                max_tokens=max_tokens,
            )
            break
        # except client.chat.error.RateLimitError:
        #     pass
        except Exception as e:
            print(e)
        time.sleep(NUM_SECONDS_TO_SLEEP)

    return response.choices[0].message.content

# %%
def parse_score(review):
    try:
        score_pair = review.split('\n')[0]
        score_pair = score_pair.replace(',', ' ')
        sp = score_pair.split(' ')
        if len(sp) == 2:
            return [float(sp[0]), float(sp[1])]
        else:
            print('error', review)
            return [-1, -1]
    except Exception as e:
        print(e)
        print('error', review)
        return [-1, -1]

# %%
reviews = []
num_eval = 300
for ques, ans1, ans2, context in tqdm(zip(questions[:num_eval], answer1[:num_eval], answer2[:num_eval], contexts[:num_eval]), total=num_eval, desc="Evaluating"):
    content = (f'[Context]\n{context}\n\n'
               f'[Question]\n{ques["text"]}\n\n'
               f'[{role} 2]\n{ans2["text"]}\n\n[End of {role} 2]\n\n'
               f'[{role} 1]\n{ans1["text"]}\n\n[End of {role} 1]\n\n'
               f'[System]\n{prompt}\n\n'
               )
    review = get_eval(content, max_tokens=1024)
    reviews.append(review)
    # print(review)
print(len(reviews))
# Out:
# Evaluating: 100%|██████████| 300/300 [17:25<00:00,  3.48s/it]
# 300

# %%
scores_cache = []
# Out:
# ['7 6\nBoth Assistant 1 and Assistant 2 provided relevant responses by acknowledging that the ingredients in the image can be used to make a cupcake. However, they both lacked specific details and did not mention the key elements of the recipe provided in the context, such as the flavor (Wild Blackberry Vanilla Cupcakes), the baking instructions, and the icing recommendation. Assistant 1\'s response was slightly more helpful as it mentioned a "unique twist," which could imply the inclusion of blackberries in the cupcakes. Assistant 2\'s response was also relevant but lacked any additional insights or details. Overall, both responses could be improved by including more specific information from the context to enhance accuracy and helpfulness.', '6 6\nBoth Assistant 1 and Assistant 2 provided responses that are somewhat relevant to the question asked, as they both mention a baking process involving sugar, flour, butter, and eggs. However, the responses lack accuracy and detail in addressing the specific dish described in the context, which is Stuffed Flounder La Fourche. The assistants did not mention any seafood ingredients or the stuffing process described in the context, leading to a significant gap in accuracy. Additionally, the responses did not capture the essence of the dish or provide a clear and detailed explanation of how the food should be prepared based on the context given. Overall, while the responses touch on baking, they miss the mark in terms of addressing the specific dish and its preparation method accurately.', '7 7\nBoth Assistant 1 and Assistant 2 provided identical responses, which correctly identified the cooking method used for the food in the image as a microwave cooking method. They both mentioned the process of heating a mixture of sugar, butter, and milk in the microwave until the sugar dissolves and the butter melts, highlighting the convenience and quickness of this method. The responses were relevant to the question and accurate in terms of the cooking method described. However, since the question specifically asked about the cooking method for the food shown in the image, the assistants did not address the actual dish of Rosemary Roasted Almonds described in the context. Therefore, while the responses were helpful and accurate in identifying the cooking method, they lacked details and specificity related to the dish depicted in the context.', "7 8\nBoth Assistant 1 and Assistant 2 provided responses that were somewhat helpful and relevant to the question asked. They both mentioned a dish involving shrimp, potatoes, onions, garlic, lemon, and seasoning mix, which is completely unrelated to the recipe described in the context. However, Assistant 2's response was slightly more accurate as it included more specific details about the ingredients mentioned in the image. Both responses lacked accuracy and failed to address the actual recipe described in the context. Additionally, both responses lacked details and did not provide any information that could guide the user towards understanding the recipe mentioned in the context. Overall, Assistant 2 performed slightly better due to the inclusion of more specific details, earning a score of 8, while Assistant 1 receives a score of 7 for providing a similar but less detailed response.", '6 7\nAssistant 1 provided a response that was somewhat relevant to the question, mentioning ingredients and cooking methods, but it did not address the specific preparation steps outlined in the context. The details provided were somewhat accurate but lacked precision in matching the context. The response lacked information on the actual preparation method described in the context, which affected its helpfulness. The overall score is 6.\n\nAssistant 2 gave a response that was somewhat relevant to the question, mentioning ingredients and cooking methods, but it did not address the specific preparation steps outlined in the context. The details provided were somewhat accurat ...

# %%
scores = []
for review in reviews:
    score = parse_score(review)
    scores.append(score)
scores = np.array(scores)
avg = np.mean(scores, axis=0)
print(f"Ours: {avg[0]} / 10 \nLLaVA-7B: {avg[1]} / 10")
# Out:
# Ours: 7.04 / 10
# LLaVA-7B: 6.173333333333333 / 10
